# %% [markdown]
# <a href="https://colab.research.google.com/github/rizkimahesa/UTS-PDT_Kelompok-Vengeance_AB/blob/main/UTS_PDT_Kelompok_Vengeance_AB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NO 1

# %%
import pandas as pd

# Load the dataset from the correct URL pointing directly to the CSV file
url = 'https://raw.githubusercontent.com/rizkimahesa/UTS-PDT_Kelompok-Vengeance_AB/main/indian_store.csv'
df = pd.read_csv(url)
df
# Out:
#                                         Product Name  Product Category  \
# 0                      Organic Tattva Cinnamon Stick  Organic Products
# 1                        24 Mantra Organic Moong Dal  Organic Products
# 2               24 Mantra Organic Himalaya Pink Salt  Organic Products
# 3                  Organic Tattva Mustard Seed Black  Organic Products
# 4                  24 Mantra Organic Rice Flour Fine  Organic Products
# ...                                              ...               ...
# 5688      Sukhadia Garbaddas Bapuji Snack - Tal Puri    Snacks & Chips
# 5689       Sukhadia Garbaddas Bapuji Snack - Tam Tam    Snacks & Chips
# 5690  Sukhadia Garbaddas Bapuji Snack - Wheat Chevdo    Snacks & Chips
# 5691                          Tb Snk- Ribbon Murukku    Snacks & Chips
# 5692                                  Uttam Sev Puri    Snacks & Chips
#
#      Product Price  Product Price (INR) Quantity
# 0            $2.84               154.07      50g
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5693 entries, 0 to 5692
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         5693 non-null   object
#  1   Product Category     5693 non-null   object
#  2   Product Price        5693 non-null   object
#  3   Product Price (INR)  5693 non-null   float64
#  4   Quantity             5693 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 222.5+ KB

# %%
df = df.drop (columns = ['Product Name','Product Category'])

# %%
df['Product Price'] = df['Product Price'].apply(lambda x: df['Product Price'].unique().tolist().index(x))
df['Quantity'] = df['Quantity'].apply(lambda x: df['Quantity'].unique().tolist().index(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5693 entries, 0 to 5692
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Price        5693 non-null   int64
#  1   Product Price (INR)  5693 non-null   float64
#  2   Quantity             5693 non-null   int64
# dtypes: float64(1), int64(2)
# memory usage: 133.6 KB

# %%
median = df['Product Price'].median()
median_price = df['Product Price (INR)'].median()
median_quantity = df['Quantity'].median()
print("Median", median)
print("Median", median_price)
print("Median", median_quantity)
# Out:
# Median 370.0
# Median 267.45
# Median 25.0

# %%
mean = df['Product Price'].mean()
mean_price = df['Product Price (INR)'].mean()
mean_quantity = df['Quantity'].mean()
print("mean", mean)
print("mean price", mean_price)
print("mean quantity", mean_quantity)
# Out:
# mean 509.71526435974005
# mean price 493.0405972246619
# mean quantity 76.4626734586334

# %%
total_count = len(df)
print("Total data:", total_count)
# Out:
# Total data: 5693

# %% [markdown]
# # NO 2

# %%
url = 'https://raw.githubusercontent.com/rizkimahesa/UTS-PDT_Kelompok-Vengeance_AB/main/Data%20Kursi%20kereta.csv'
df = pd.read_csv(url)
df
# Out:
#     No Bangku Kreta Keterangan         Nama Penumpang
# 0                 1      Habis           Rizki Mahesa
# 1                 2   Tersedia           Belum Terisi
# 2                 3   Tersedia           Belum Terisi
# 3                 4      Habis         Septia Rosalia
# 4                 5      Habis   Bianka Zahirra Putri
# 5                 6      Habis          Luthfi Aditya
# 6                 7      Habis  Eric Sanjaya Sipayung
# 7                 8   Tersedia           Belum Terisi
# 8                 9   Tersedia           Belum Terisi
# 9                10   Tersedia           Belum Terisi
# 10               11   Tersedia           Belum Terisi
# 11               12      Habis  Maharani Wahyu Tantri
# 12               13      Habis           Devina Citra
# 13               14      Habis      Anindya Salsabila
# 14               15   Tersedia           Belum Terisi

# %%
kursi_tersedia = df[df['Keterangan'] == 'Tersedia']['No Bangku Kreta'].tolist()
kursi_habis = df[df['Keterangan'] == 'Habis']['No Bangku Kreta'].tolist()

# %%
jumlah_habis= df['Keterangan'].value_counts()['Habis']
jumlah_tersedia= df['Keterangan'].value_counts()['Tersedia']

# %%
print("Kursi yang masih tersedia:", kursi_tersedia)
print("Jumlah kursi yang masih tersedia:", jumlah_tersedia)
print("kursi yang habis:", kursi_habis)
print("Jumlah kursi yang habis:", jumlah_habis)
# Out:
# Kursi yang masih tersedia: [2, 3, 8, 9, 10, 11, 15]
# Jumlah kursi yang masih tersedia: 7
# kursi yang habis: [1, 4, 5, 6, 7, 12, 13, 14]
# Jumlah kursi yang habis: 8
